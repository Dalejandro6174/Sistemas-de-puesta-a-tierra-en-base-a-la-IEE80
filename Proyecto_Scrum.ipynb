# %%
import math as m
import os
import platform
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm



def borrarPantalla():

    '''
    La función borrar pantalla,funciona cuando el programa se ejecuta desde una
    terminal. Si el programa se ejecuta desde el IDLE de python, esta función no
    será reconocida por el programa, ya que el IDLE no es una terminal de sis-
    tema operativo, sino un programa hecho en  Python Tekinter.

    '''
##
##    if platform.system() == "Linux":
##
##       os.system("clear")
##
##    else:
##
##       os.system("clS")

#-------------------------------------------------------------------------------------
##$borrarPantalla()
#print ("\n" * (4))
print ("*************************************************************************\n")
print("DISEÑO DE MALLA DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR, CUADRADA ")
print("Y EN FORMA DE 'L' SEGÚN NORMA IEEE-80/2000")
print("V2022_1")
print("ELABORADO POR: MARIO LEÓN HOYOS LONDOÑO")
print("MAYO DE 2022")
print("EMPRESA ENERVOLT S.A.S.")
print ("*************************************************************************\n")
#print("NOTA: Luego de ingresar información  'ENTER' para confimar y continuar.")
#print ("-------------------------------------------------------------------------\n" * (1))
#input()
#-----------------------------------------------------------------------------------------
#borrarPantalla()
##print ("\n" * (1))
print ("*************************************************************************\n")
print("SELECCIONE EL NÚMERO CORRESPONDIENTE AL TIPO DE SUBESTACIÓN:")
print ("-------------------------------------------------------------------------\n")
print("1) Subestaciones de alta y extra alta tensión  ")
print("2) Subestaciones de media tensión en poste ")
print("3) Subestaciones de media tensión de uso interior ")
flag1 =  int(input(" Número tipo de subestación = "))

while True:
    if flag1==1:
        res_menor = 1
        break

    elif flag1==2:

        res_menor = 10
        break
    elif flag1==3:

        res_menor = 5
        break

resisti_apare=9
while resisti_apare < 10 or resisti_apare > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n" )
        print("INGRESE EL VALOR DE LA RESISTIVIDAD APARENTE DEL TERRENO HOMOGENEO")
        print ("*************************************************************************\n" )
        print("     ")
        print("---------------------------------------------------------------------------")
        resisti_apare= float(input("Resitivad aparente [Ohm_m] = "))
        print("---------------------------------------------------------------------------")

I_Falla=99
while I_Falla < 100 or I_Falla > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n")
        print("INGRESE CORRIENTE LA DE FALLA DE SECUENCIA CERO EN EL SECUNDARIO DE LA S/E 3I0s")
        print ("*************************************************************************\n")
        print("100A < IF < 20.000A ")
        print("---------------------------------------------------------------------------")
        I_Falla =  float(input("Corriente de falla 1F [A] = "))
I_Falla1=99
while I_Falla1 < 100 or I_Falla1 > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n")
        print("INGRESE CORRIENTE DE FALLA DE SECUENCIA CERO EN EL PRIMARIO DE LA S/E 3I0p")
        print ("*************************************************************************\n" )
        print("100A < IF < 20.000A ")
        print("---------------------------------------------------------------------------")
        I_Falla1 =  float(input("Corriente de falla 1F [A] = "))

I03 = I_Falla1

borrarPantalla()
print (" \n" )
print ("*************************************************************************\n")
print("INGRESE EL FACTOR DIVISOR DE CORRIENTE DE FALLA Sf DE LA SUBESTACIÓN")
print ("*************************************************************************\n")
print("---------------------------------------------------------------------------")
Sf = float(input("Division de corriente de falla Sf = "))

Tc=49
while Tc < 50 or Tc > 500:
        borrarPantalla()
        print (" \n")
        print ("*************************************************************************\n")
        print("INGRESE TIEMPO DE  DESPEJE DE FALLA EN [ms]")
        print ("*************************************************************************\n" )
        print("50ms < t < 500ms ")
        print("---------------------------------------------------------------------------")
        Tc = float(input(" Tiempo de despeje de falla[ms] = "))

borrarPantalla()
print (" \n" * (1))
print ("*************************************************************************\n" )
print("SELECCIONE EL TIPO DE MATERIAL UTILIZADO PARA LA  PUESTA  TIERRA:")
print ("*************************************************************************\n" )
print("1) Cobre blando  ")
print("2) Cobre duro. Cuando se utiliza soldadura exotérmica")
print("3) Cobre duro. Cuando se utilizan conexiones mecánicas a presión ")
print("4) Alambre de acero recubierto de cobre  ")
print("5) Varilla de acero recubierta de cobre ")
print("6) Varilla de acero galvanizada ")
print("Temperatura 40° ")
print("---------------------------------------------------------------------------")
flag2= int(input("Número material seleccionado = "))

if flag2==1:
    Kf=7
    M = "1) Cobre blando  "
elif flag2==2:
    Kf=7.06
    M = "Cobre duro cuando se utiliza soldadura exotérmica"
elif flag2==3:
    Kf=11.78
    M = "Cobre duro cuando se utilizan conexiones mecánicas a presión "
elif flag2==4:
    Kf=10.45
    M = "Alambre de acero recubierto de cobre"
elif flag2==5:
    Kf=14.64
    M = "Varilla de acero recubierta de cobre "
elif flag2==6:
    Kf=14.72
    M = "Varilla de acero galvanizada "
else:
    print("No ingresó un dato correcto")
borrarPantalla()
print (" \n" * (1))
print ("*************************************************************************\n" )
print("SELECCIONE INFORMACIÓN SOBRE CAPA SUPERFICIAL:")
print ("*************************************************************************\n" )
print("1) Si hay capa superficial ")
print("2) No hay capa superficial")
print("---------------------------------------------------------------------------")
flag3 = int(input("Capa suerficial[Si=1, No =2] = "))

if flag3==1:
    borrarPantalla()
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("INGRESE VALOR DE RESISTIVIDAD DE LA CAPA SUPERFICIAL en[Ohm_m]:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    resisti = float(input("Resistividad Capa superficial [Ohm_m] = "))

    print (" \n" )
    print ("*************************************************************************\n")
    print("INGRESE ESPESOR DE LA CAPA SUPERFICIAL en[cm]:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    hs = float(input("Espesor =  "))

elif flag3==2:
    resisti=resisti_apare
    hs=0
else:
    print("No ingresó un dato correcto")
# Cálculo de Aŕea mínima

A_min=((I_Falla/1000)*Kf*m.sqrt(Tc/1000))/1.974

if A_min < 67.45:
    calibre = "2/0 AWG"
elif 67.45 <= A_min<107.23:
    calibre ="4/0 AWG"
elif 107.23 <= A_min<126.69:
    calibre = "250 kcmil"
elif 126.69 <= A_min<152.02:
    calibre ="300 kcmil"
else:
    calibre="350 kcmil"

if calibre =="2/0 AWG":
    diam = 0.0093
elif calibre == "4/0 AWG":
    diam = 0.0117
elif calibre == "250 kcmil":
    diam = 0.0127
elif calibre == "300 kcmil":
    diam = 0.0139
elif calibre == "350 kcmil":
    diam = 0.015
else:
    print("Error al elegir el diámetro")


borrarPantalla()
print (" \n")
print ("*************************************************************************\n" )
print("SELECCIONE LA GEOMETRÍA DE LA MALLA:")
print ("*************************************************************************\n")
print("---------------------------------------------------------------------------")
print("1) Geometría Cuadrada  ")
print("2) Geometría Retangular")
print("3) Geometría en forma de 'L'")
flag4 = int(input("Número Geometría seleccionada = "))

if flag4==1:
    borrarPantalla()
    tipomalla = f" Geometría Cuadrada "
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("DIMENSIONES MALLA GEOMETRÍA CUADRADA")
    print ("*************************************************************************\n" )
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("INGRESE LA LONGITUD DEL LADO DE LA MALLA:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    largo = float(input("Longiud [m] = "))
    ancho=largo
    # L1, l2, es una característica de las mallas en forma de 'L'
    l1=0
    l2=0
elif flag4==2:
    tipomalla = f" Geometría Rectangular"
    borrarPantalla()
    print (" \n")
    print ("*************************************************************************\n")
    print("DIMENSIONES MALLA GEOMETRÍA RECTANGULAR")
    print ("*************************************************************************\n")
    print (" \n" )
    print ("*************************************************************************\n")
    print("INGRESE LADO DE MAYOR LONGITUD [m]:")
    print ("*************************************************************************\n")
    print("---------------------------------------------------------------------------")
    largo=float(input("Largo[m] = : "))
    print (" \n")
    print ("*************************************************************************\n")
    print("INGRESE LADO DE MENOR LONGITU[m] =")
    print ("*************************************************************************\n")
    print("---------------------------------------------------------------------------")
    ancho=float(input("Ancho[m] = "))
    l1=0
    l2=0
elif flag4==3:
    tipomalla = f" Geometría en forma de 'L'"
    borrarPantalla()
    print("    *******l1******     ")
    print("   L*             *     ")
    print("   A*             *     ")
    print("   R*             *     ")
    print("   G*             *     ")
    print("   O*             *     ")
    print("    *             **************    ")
    print("    *                          *    ")
    print("    *                          * L2 ")
    print("    *                          *    ")
    print("    ***********ANCHO************    ")
    print (" \n")
    print ("*************************************************************************\n" )
    print("DIMENSIONES MALLA GEOMETRÍA EN 'L'")
    print ("*************************************************************************\n" )
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO DE MAYOR LONGITUD DE LA 'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    largo=float(input("Largo[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO DE MENOR LONGITUD DE LA 'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    ancho=float(input("Ancho[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO L1 DE LA'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    l1=float(input("L1[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO L2 DE LA'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    l2=float(input("L2 =  "))
borrarPantalla()
# La cuadrícula es las subdivision de los lados de la malla
print (" \n")
print ("*************************************************************************\n" )
print("INGRESE LONGITUD DEL LADO DE LA CUADRÍCULA DE LA MALLA[cm]:")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
lado_cuadri = float(input("Longitud cuadrícula[cm] = "))

if flag4==1 or flag4==2:

    longi_conduc_horiz=((largo/(lado_cuadri/100))+1)*ancho+((ancho/(lado_cuadri/100))+1)*largo
elif flag4==3:
    longi_conduc_horiz=((largo/(lado_cuadri/100))+1)*l1+((l1/(lado_cuadri/100))+1)*largo+(((ancho-l1)/(lado_cuadri/100)))*l2+((l2/(lado_cuadri/100))+1)*(ancho-l1)

borrarPantalla()
print (" \n")
print ("*************************************************************************\n" )
print("EL DISEÑO PRELIMINAR TIENE VARILLAS?")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
print("1) Si tiene varillas  ")
print("2) No tiene varillas")
print("---------------------------------------------------------------------------")
flag=int(input())

if flag==1:

    borrarPantalla()
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LA LONGITUD DE LAS VARILLAS[cm]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    longi_vari=int(input("Longitud Varillas[cm] = "))


    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE EL NÚMERO DE VARILLAS")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    num_vari=int(input("Cantidad de varillas = "))

    longi_total_vari=num_vari*longi_vari/100

elif flag==2:

    num_var=0
    longi_vari=0
    longi_total_vari=0
else:

    print("Ingresó una opción inválida")
# Longitud de las varillas según para el diseño preliminar
longi_perim = 2*(largo+ancho)


borrarPantalla()
print (" \n" )
print ("*************************************************************************\n" )
print("INGRESE LA PROFUNDIDAD DE ENTERRAMIENTO DE LA MALLA[cm]")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
prof_enterra = int(input("Profundidad[cm] = "))

if flag4==1 or flag4==2:
    area_malla=largo*ancho
elif flag4==3:
    area_malla = (largo*l1)+l2*(ancho-l1)
else:
    print("Error")
borrarPantalla()
print (" \n" * (2))
print ("*************************************************************************\n" )
print("INGRESE PESO APROXIMADO DE UNA PERSONA SOBRE LA MALLA")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
print("1) 50KG  ")
print("2) 70KG")
flag5 = int(input("Número de peso seleccionado = "))

# Tensiones de paso y de contacto
Cs = 1-(0.09*(1-(resisti_apare/resisti))/((2*hs/100)+0.09))

if flag5==1:
    t_contac_tolerable=(1000+1.5*Cs*resisti)*0.116/m.sqrt(Tc/1000)
    t_paso_tolerable=(1000+6*Cs*resisti)*0.116/m.sqrt(Tc/1000)
elif flag5==2:
    t_contac_tolerable=(1000+1.5*Cs*resisti)*0.157/m.sqrt(Tc/1000)
    t_paso_tolerable=(1000+6*Cs*resisti)*0.157/m.sqrt(Tc/1000)
else:
    print("No seleccionó una opción válida")

t_contac_tolerable50=(1000+1.5*Cs*resisti)*0.116/m.sqrt(Tc/1000)
t_paso_tolerable50=(1000+6*Cs*resisti)*0.116/m.sqrt(Tc/1000)

t_contac_tolerable70=(1000+1.5*Cs*resisti)*0.157/m.sqrt(Tc/1000)
t_paso_tolerable70=(1000+6*Cs*resisti)*0.157/m.sqrt(Tc/1000)

# Resistencias de puesta a tierra

res_puesta_tierra=resisti_apare*((1/(longi_conduc_horiz+longi_total_vari))+(1/m.sqrt(20*area_malla))*(1+(1/(1+prof_enterra*m.sqrt(20/area_malla)/100))))

# Cálculo de la tensión de la malla

C45=2*longi_conduc_horiz/longi_perim
D45=m.sqrt(longi_perim/(4*m.sqrt(area_malla)))

if flag4==1 or flag4==2:
    E45=1
elif flag4==3:
    E45=(largo*ancho/area_malla)**(0.7*area_malla/(largo*ancho))

else:
    print("Error en el ingreso de datos")

n=C45*D45*E45# n

if flag==1:
    H45=1
elif flag==2:
    H45=1/(2*n)**(2/n)


G45=m.sqrt(1+0.01*prof_enterra)


ki=0.644+0.148*n # ki


ks=(1/m.pi)*((1/(2*prof_enterra/100))+(1/((lado_cuadri/100)+(prof_enterra/100)))+(100/lado_cuadri)*(1-0.5**(n-2)))


km = (1/(2*m.pi))*(m.log1p((((lado_cuadri*0.01)**2)/(16*prof_enterra*0.01*diam))+(((lado_cuadri*0.01+2*0.01*prof_enterra)**2)/(8*lado_cuadri*0.01*diam))-((prof_enterra*0.01)/(4*diam))-1)+((H45/G45)*m.log1p(8/(m.pi*((2*n)-1))-1)))
# Se calcula la máxima corriente de malla
# 0,6 ; I03 datos de la subestación del diseño
IG = (1)*(Sf)*(I03)
##print("Resitividad = ",resisti_apare)
##print("n = ",n)
##print(" km = ",km)
##print(" ks = ",ks)
##print(" ki = ",ki)
##print("Longitud total =",longi_conduc_horiz)
##print("IG =",IG)
##input()
# GPR
GPR = round(IG) * round(res_puesta_tierra,2)

Em =(resisti_apare*IG*km*ki)/(longi_conduc_horiz+(1.55+1.22*(longi_vari*0.01/(m.sqrt(largo**2+ancho**2))))*longi_total_vari)

Es =(resisti_apare*IG*ks*ki)/(0.75*longi_conduc_horiz+0.85*longi_total_vari)
borrarPantalla()

print (" \n")
print ("*************************************************************************\n")
print("DATOS DISEÑO PRELIMINAR:")
print ("*************************************************************************\n")
print(f'''
Diseño de malla de puesta a tierra {tipomalla }
________________________________________________________________________________
Resistencia objetivo menor = {res_menor}[Ohm]
________________________________________________________________________________
Resistividad aparente del terreno = {resisti_apare}[Ohm_m]
________________________________________________________________________________
Corriente de falla trifasica a tierra en el primario = {I_Falla}[A]
________________________________________________________________________________
Tiempo de despeje de la malla  = {Tc}[ms]
________________________________________________________________________________
Material del conductor: {M}[40°C]
________________________________________________________________________________
Resisitividad capa superficial = {resisti} [Ohm_m]
________________________________________________________________________________
Diámetro del conductor = {diam}[mm]      Calibre sugerido: {calibre}
________________________________________________________________________________
Longitud conductor horizontal = {longi_conduc_horiz}[m]
________________________________________________________________________________
Longitud total de varillas = {longi_total_vari}[m]
________________________________________________________________________________
Longitud total del perímetro = {longi_perim}[m]
________________________________________________________________________________
Área de la malla = {area_malla}[m^2]
_______________________________________________________________________________
Tensión de paso 50kg = {round(t_paso_tolerable50,3)} [V]
_______________________________________________________________________________
Tensión de contacto 50kg = {round(t_contac_tolerable50,3)} [V]
________________________________________________________________________________
Tensión de paso 70kg = {round(t_paso_tolerable70,3)} [V]

Tensión de contacto 70kg = {round(t_contac_tolerable70,3)} [V]
________________________________________________________________________________

Resistencia de puesta a tierra = {round(res_puesta_tierra,2)}[Ohms]
_______________________________________________________________________________
Máxima corriente de malla  {round(IG)} [A]     GPR = {GPR}[V]
_______________________________________________________________________________

Tensión de malla Em = {Em} [V]     Enter para continuar...
_______________________________________________________________________________

''')
input()

borrarPantalla()
if GPR > t_contac_tolerable:

    com1 = "El GPR"
    com2 = "el voltaje de contacto tolerable"
    d1 = 0
else:

    com1 = "El voltaje de contacto tolerable"
    com2 = "GPR"
    d1 = 1

if Em > t_contac_tolerable:

    com3 = "El Voltaje de malla"
    com4 = "el voltaje de contacto tolerable"
    d2 = 0
else:

    com3 = "El voltaje de contacto tolerable "
    com4 = "el Voltaje de malla"
    d2 = 1

if Es > t_paso_tolerable:

    com5 = "El Voltaje de paso calculado"
    com6 = "el voltaje de paso tolerable"
    d3 = 0
else:

    com5 = "El voltaje de paso tolerable"
    com6 = "el Voltaje de paso calculado"
    nota1 ="Se cumple con la resistencia mínima sugerida"
    d3 = 1

if res_puesta_tierra > res_menor:

    com7 = "La resistencia calculada"
    com8 = "la mínima reistencia sugerida por el RETIE"
    nota1 = f'''
    Si no es posible obtener una resistencia de puesta a tierra por debajo
    de los límites sugeridos por el RETIE, se puede continuar con la constr-
    ucción  de la malla, siempre y cuando se cumpla con los criterios
    de tensión de contacto y de paso mínimos tolerables.
    '''
    d4 = 0
else:

    com7 = "La mínima reistencia sugerida RETIE"
    com8 = "la resistencia calculada"
    d4 = 1

n = d2*d3

if n == 0:
    diag = "Modigique su diseño"
else:
    diag = "Diseño exitoso! "

borrarPantalla()
print (" \n")
print(f'''

********************************************************************************
ANÁLISI COMPARATIVO
********************************************************************************
GPR = {GPR}
-------------------------------------------------------------------------------
Voltaje de contacto tolerable  = {round(t_contac_tolerable,3)}[V]

Voltaje de malla  = {round(Em,3)}[V]

{com3} es mayor que {com4}
-------------------------------------------------------------------------------

Vpaso tolerable = {round(t_paso_tolerable,3)}[V]

Vpaso caculado =  {round(Es,3)} [V]

{com5} es mayor que {com6}
-------------------------------------------------------------------------------

Resistencia de puesta a tierra sugerida =  {res_menor}[Ohms]

Resistencia de puesta tierra malla =  {round(res_puesta_tierra,2)}[Ohms]

{com7} es mayor que {com8}

Nota : {nota1}
-------------------------------------------------------------------------------
Diagnóstico : {diag}
_______________________________________________________________________________

''')
"""
Se calculael numero de cruces en forma de X,L y T
"""
input()
if flag4==1 or flag4==2:
    lado_cuadri_m=lado_cuadri/100
    nL=4
    nx=((largo/lado_cuadri_m)-1)*((ancho/lado_cuadri_m)-1)
    nT=(((largo/lado_cuadri_m)-1)+((ancho/lado_cuadri_m)-1))*2
    forma=("Rectangular")
elif flag4==3:
    nL=5
    lado_cuadri_m=lado_cuadri/100
    nx=1+((largo/lado_cuadri_m)-1)*((l1/lado_cuadri_m)-1)+((l2/lado_cuadri_m)-1)*((ancho-l1)/lado_cuadri_m)
    nT=((2*(ancho+largo))/lado_cuadri_m)-6
    forma=("forma L")
"""
Añadimos un diccionario con la cantidad de soldadura por calibre

"""

LibreriaT={
   "2/0 AWG":90 ,
   "4/0 AWG":150 ,
   "250 kcmil":150 ,
   "300 kcmil":200 ,
   "350 kcmil":200
   }
LibreriaX={
   "2/0 AWG":115 ,
   "4/0 AWG":200 ,
   "250 kcmil":200 ,
   "300 kcmil":250 ,
   "350 kcmil":250
   }
LibreriaL={
   "2/0 AWG":90 ,
   "4/0 AWG":150 ,
   "250 kcmil":150 ,
   "300 kcmil":200 ,
   "350 kcmil":200
   }
PrecioSoldadura={
    90: 13800,
    115:16800,
    150:21900,
    200:26200,
    250:32550,
   }
PrecioCobreDuro={
   "2/0 AWG":43200 ,
   "4/0 AWG":67200 ,
   "250 kcmil":80150 ,
   "300 kcmil":95000 ,
   "350 kcmil":112250
   }
SoldaduraT=LibreriaT[calibre]
SoldaduraL=LibreriaL[calibre]
SoldaduraX=LibreriaX[calibre]
PrecioT=PrecioSoldadura[SoldaduraT]
PrecioL=PrecioSoldadura[SoldaduraL]
PrecioX=PrecioSoldadura[SoldaduraX]
PrecioCobre=PrecioCobreDuro[calibre]
print(f'''

********************************************************************************
CANTIDAD DE CRUCES EN EL CIRCUITO
********************************************************************************
La malla tiene forma {forma}
-------------------------------------------------------------------------------

Numero de cruces L:{nL}
Soldadura por cruce : {SoldaduraL} gr
Precio Unitario:{PrecioL}
Precio total soldadura .exo L:{PrecioL*nL} COP

-------------------------------------------------------------------------------

Numero de cruces T:{nT}
Soldadura por cruce : {SoldaduraT} gr
Precio Unitario:{PrecioT}
Precio total soldadura .exo T:{PrecioT*nT} COP

-------------------------------------------------------------------------------

Numero de cruces X:{nx}
Soldadura por cruce : {SoldaduraX} gr
Precio Unitario:{PrecioX}
Precio total soldadura .exo L:{PrecioX*nx} COP

-------------------------------------------------------------------------------

PRECIO TOTAL POR SOLDADURA EXOTERMICA: {PrecioX*nx+PrecioT*nT+PrecioL*nL} COP

-------------------------------------------------------------------------------
El total de longitud total de la malla :{round(longi_conduc_horiz)}  [m]

De un calibre minimo sugerido de {calibre}
_______________________________________________________________________________

''')

input()


if flag==1:
    print(f'''

********************************************************************************
Varillas
********************************************************************************
El numero de varillas son {num_vari} , de una longitud {longi_vari} [cm]

Para una longitud total entre varillas y malla de :{round(longi_conduc_horiz)+longi_vari*0.01} [m]
El precio por metro es   :{PrecioCobre} COP
Precio total de longitud :{(round(longi_conduc_horiz)+longi_vari)*PrecioCobre} COP
_______________________________________________________________________________

''')


"""
Se realiza el dibujo de la malla de puesta a tierra
"""
if flag4==1 or flag4==2:
    lado_cuadri_m=lado_cuadri/100
    n_largo=int((largo/lado_cuadri_m)+1)
    n_ancho=int((ancho/lado_cuadri_m)+1)

    x,y=np.linspace(0,ancho,n_ancho),np.linspace(0,largo,n_largo)
    # Valores de x, y para cuadrícula de la malla
    X,Y=np.meshgrid(x,y)
    # Ecuación zn = f(x,y)
    Z1=Y


    fig=plt.figure()
    ax=fig.add_subplot(projection='3d')
    # alpha da la tranparencia a la superficie
    #ax.plot_surface(X,Y,Z1,alpha=0.9,cmap=cm.Accent,rstride=100,cstride=100)
    ax.plot_wireframe(X,Y,Z1,alpha=1,rstride=1,cstride=1)
    #ax.plot_surface(X,Y,Z2,alpha= 0.9,cmap=cm.Paired,rstride=100,cstride=100)
    #ax.plot_surface(X,Y,Z3,alpha=0.9,cmap=cm.Pastel1,rstride=100,cstride=100)
    plt.title("Malla")
    plt.show()
elif flag4==3:

    lado_cuadri_m=lado_cuadri/100
    n_largo=int((largo/lado_cuadri_m)+1)
    n_ancho=int((l1/lado_cuadri_m)+1)
    n_xmalla2=int(((ancho-l1)/lado_cuadri_m)+1)
    n_ymalla2=int(((l2)/lado_cuadri_m)+1)

    x,y=np.linspace(0,l1,n_ancho),np.linspace(0,largo,n_largo)
    x2,y2=np.linspace(l1,ancho,n_xmalla2),np.linspace(0,l2,n_ymalla2)
    # Valores de x, y para cuadrícula de la malla
    X,Y=np.meshgrid(x,y)
    # Ecuación zn = f(x,y)
    X2,Y2=np.meshgrid(x2,y2)
    Z1=Y
    Z2=Y2
    fig=plt.figure()
    ax=fig.add_subplot(projection='3d')
    # alpha da la tranparencia a la superficie
    #ax.plot_surface(X,Y,Z1,alpha=0.9,cmap=cm.Accent,rstride=100,cstride=100)
    ax.plot_wireframe(X,Y,Z1,alpha=1,rstride=1,cstride=1)
    ax.plot_wireframe(X2,Y2,Z2,alpha=1,rstride=1,cstride=1)
# Out:
# *************************************************************************
#
# DISEÑO DE MALLA DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR, CUADRADA
# Y EN FORMA DE 'L' SEGÚN NORMA IEEE-80/2000
# V2022_1
# ELABORADO POR: MARIO LEÓN HOYOS LONDOÑO
# MAYO DE 2022
# EMPRESA ENERVOLT S.A.S.
# *************************************************************************
#
# *************************************************************************
#
# SELECCIONE EL NÚMERO CORRESPONDIENTE AL TIPO DE SUBESTACIÓN:
# -------------------------------------------------------------------------
#
# 1) Subestaciones de alta y extra alta tensión
# 2) Subestaciones de media tensión en poste
# 3) Subestaciones de media tensión de uso interior
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-03c885335503> in <cell line: 53>()
# ...

# %%
#PROGRAMA PARA DISEÑO DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR
import math as m
import os
import platform
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

def borrarPantalla():

    '''
    La función borrar pantalla,funciona cuando el programa se ejecuta desde una
    terminal. Si el programa se ejecuta desde el IDLE de python, esta función no
    será reconocida por el programa, ya que el IDLE no es una terminal de sis-
    tema operativo, sino un programa hecho en  Python Tekinter.

    '''
##
##    if platform.system() == "Linux":
##
##       os.system("clear")
##
##    else:
##
##       os.system("clS")

#-------------------------------------------------------------------------------------
##$borrarPantalla()
#print ("\n" * (4))
#graficas


def plot_circle_with_points(r_exterior, r_interior, angle1, angle2):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior*1.1)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()





def plot_circle_with_points1(r_exterior, r_interior, angle1, angle2, angle3):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior*1.1)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()





def plot_circle_with_points2(r_exterior, r_interior, angle1, angle2, angle3,angle4 ):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior*1.1)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()





def plot_circle_with_points3(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+3)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()



def plot_circle_with_points4(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+3.5)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()


def plot_circle_with_points5(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+3.5], 'g',label="l = 5m")
    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde adicional desde (1.5, 90) de radio
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+5], 'g',label="l = 5m")


    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+3.5)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()


def plot_circle_with_points6(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde adicional desde (1.5, 90) de radio
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+5], 'g',label="l = 5m")
    ax.plot([np.deg2rad(270), np.deg2rad(270)], [r_exterior, r_exterior+5], 'g',label="l = 5m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+5)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()


def plot_circle_with_points7(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+10], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()



def plot_circle_with_points8(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+8.5], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+10], 'g')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()



def plot_circle_with_points9(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+8.5], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+10], 'g')
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+ 10], 'g')


    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()



def plot_circle_with_points10(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+10], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+10], 'g')
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+ 10], 'g')
    ax.plot([np.deg2rad(270), np.deg2rad(270)], [r_exterior, r_exterior+10], 'g')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()

respuesta = input("¿Desea ejecutar un programa para  STP tipo poste? (s/n): ")
if respuesta == "s":


    radii = [0.9, 1.5]
    theta = np.linspace(0, 2*np.pi, 100)
    resistividad = 0
    while resistividad < 100 or resistividad > 1400:
        resistividad = int(input("Ingrese la resistividad del terreno en ohm-metros (entre 100 y 1400): "))
        if resistividad >= 100 and resistividad <= 200:
            plot_circle_with_points(1.5, 0.9, 180, 90)
        elif resistividad > 200 and resistividad <= 300:
            plot_circle_with_points1(1.5, 0.9, 180, 90, 0)
        elif resistividad > 300 and resistividad <= 400:
            plot_circle_with_points2(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 400 and resistividad <= 500:
            plot_circle_with_points3(1.5, 0.9, 180, 90, 0, 270)
        elif  resistividad > 500 and resistividad <= 600:
            plot_circle_with_points4(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 600 and resistividad <= 700:
            plot_circle_with_points5(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 700 and resistividad <= 800:
            plot_circle_with_points6(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 800 and resistividad <= 900:
            plot_circle_with_points7(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 900 and resistividad <= 1000:
            plot_circle_with_points8(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 1000 and resistividad <= 1100:
            plot_circle_with_points9(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 1100 and resistividad <= 1400:
            plot_circle_with_points10(1.5, 0.9, 180, 90, 0, 270)

    # Preguntar al usuario si desea imprimir las consideraciones
    imprimir_consideraciones = input("¿Desea imprimir las consideraciones? (Sí/No): ")

    # Verificar si el usuario quiere imprimir las consideraciones
    if imprimir_consideraciones.lower() == "sí":
        # Imprimir las consideraciones
        print("Consideraciones:")
        print("• Círculo interno R1: 0,9 m desde la base del poste.")
        print("• Círculo externo R2: 1,5 metros desde la base del poste.")
        print("• L: corresponde a la longitud del contrapeso a utilizar.")
        print("• El cable o bajante de puesta a tierra se debe empalmar con el círculo interno (R1) así como con la varilla más próxima al punto donde se entierre.")
        print("• Los círculos internos (R1) y externo (R2) se deben empalmar en por lo menos dos puntos (separados 180°) por medio de soldadura exotérmica. La conexión se debe realizar para evitar la concentración de potenciales en el SPT.")
        print("• Para resistividades superiores a 2000 Ω-m se debe emplear la configuración No 11.")
    else:
        print("No se imprimirán consideraciones.")




print ("*************************************************************************\n")
print("DISEÑO DE MALLA DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR, CUADRADA ")
print("Y EN FORMA DE 'L' SEGÚN NORMA IEEE-80/2000")
print("V2022_1")
print("ELABORADO POR: MARIO LEÓN HOYOS LONDOÑO")
print("MAYO DE 2022")
print("EMPRESA ENERVOLT S.A.S.")
print ("*************************************************************************\n")
#print("NOTA: Luego de ingresar información  'ENTER' para confimar y continuar.")
#print ("-------------------------------------------------------------------------\n" * (1))
#input()
#-----------------------------------------------------------------------------------------
#borrarPantalla()
##print ("\n" * (1))
print ("*************************************************************************\n")
print("SELECCIONE EL NÚMERO CORRESPONDIENTE AL TIPO DE SUBESTACIÓN:")
print ("-------------------------------------------------------------------------\n")
print("1) Subestaciones de alta y extra alta tensión  ")
print("2) Subestaciones de media tensión en poste ")
print("3) Subestaciones de media tensión de uso interior ")
flag1 =  int(input(" Número tipo de subestación = "))

while True:
    if flag1==1:
        res_menor = 1
        break

    elif flag1==2:

        res_menor = 10
        break
    elif flag1==3:

        res_menor = 5
        break

resisti_apare=9
while resisti_apare < 10 or resisti_apare > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n" )
        print("INGRESE EL VALOR DE LA RESISTIVIDAD APARENTE DEL TERRENO HOMOGENEO")
        print ("*************************************************************************\n" )
        print("     ")
        print("---------------------------------------------------------------------------")
        resisti_apare= float(input("Resitivad aparente [Ohm_m] = "))
        print("---------------------------------------------------------------------------")

I_Falla=99
while I_Falla < 100 or I_Falla > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n")
        print("INGRESE CORRIENTE LA DE FALLA DE SECUENCIA CERO EN EL SECUNDARIO DE LA S/E 3I0s")
        print ("*************************************************************************\n")
        print("100A < IF < 20.000A ")
        print("---------------------------------------------------------------------------")
        I_Falla =  float(input("Corriente de falla 1F [A] = "))
I_Falla1=99
while I_Falla1 < 100 or I_Falla1 > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n")
        print("INGRESE CORRIENTE DE FALLA DE SECUENCIA CERO EN EL PRIMARIO DE LA S/E 3I0p")
        print ("*************************************************************************\n" )
        print("100A < IF < 20.000A ")
        print("---------------------------------------------------------------------------")
        I_Falla1 =  float(input("Corriente de falla 1F [A] = "))

I03 = I_Falla1

borrarPantalla()
print (" \n" )
print ("*************************************************************************\n")
print("INGRESE EL FACTOR DIVISOR DE CORRIENTE DE FALLA Sf DE LA SUBESTACIÓN")
print ("*************************************************************************\n")
print("---------------------------------------------------------------------------")
Sf = float(input("Division de corriente de falla Sf = "))

Tc=49
while Tc < 50 or Tc > 500:
        borrarPantalla()
        print (" \n")
        print ("*************************************************************************\n")
        print("INGRESE TIEMPO DE  DESPEJE DE FALLA EN [ms]")
        print ("*************************************************************************\n" )
        print("50ms < t < 500ms ")
        print("---------------------------------------------------------------------------")
        Tc = float(input(" Tiempo de despeje de falla[ms] = "))

borrarPantalla()
print (" \n" * (1))
print ("*************************************************************************\n" )
print("SELECCIONE EL TIPO DE MATERIAL UTILIZADO PARA LA  PUESTA  TIERRA:")
print ("*************************************************************************\n" )
print("1) Cobre blando  ")
print("2) Cobre duro. Cuando se utiliza soldadura exotérmica")
print("3) Cobre duro. Cuando se utilizan conexiones mecánicas a presión ")
print("4) Alambre de acero recubierto de cobre  ")
print("5) Varilla de acero recubierta de cobre ")
print("6) Varilla de acero galvanizada ")
print("Temperatura 40° ")
print("---------------------------------------------------------------------------")
flag2= int(input("Número material seleccionado = "))

if flag2==1:
    Kf=7
    M = "1) Cobre blando  "
elif flag2==2:
    Kf=7.06
    M = "Cobre duro cuando se utiliza soldadura exotérmica"
elif flag2==3:
    Kf=11.78
    M = "Cobre duro cuando se utilizan conexiones mecánicas a presión "
elif flag2==4:
    Kf=10.45
    M = "Alambre de acero recubierto de cobre"
elif flag2==5:
    Kf=14.64
    M = "Varilla de acero recubierta de cobre "
elif flag2==6:
    Kf=14.72
    M = "Varilla de acero galvanizada "
else:
    print("No ingresó un dato correcto")
borrarPantalla()
print (" \n" * (1))
print ("*************************************************************************\n" )
print("SELECCIONE INFORMACIÓN SOBRE CAPA SUPERFICIAL:")
print ("*************************************************************************\n" )
print("1) Si hay capa superficial ")
print("2) No hay capa superficial")
print("---------------------------------------------------------------------------")
flag3 = int(input("Capa suerficial[Si=1, No =2] = "))

if flag3==1:
    borrarPantalla()
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("INGRESE VALOR DE RESISTIVIDAD DE LA CAPA SUPERFICIAL en[Ohm_m]:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    resisti = float(input("Resistividad Capa superficial [Ohm_m] = "))

    print (" \n" )
    print ("*************************************************************************\n")
    print("INGRESE ESPESOR DE LA CAPA SUPERFICIAL en[cm]:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    hs = float(input("Espesor =  "))

elif flag3==2:
    resisti=resisti_apare
    hs=0
else:
    print("No ingresó un dato correcto")
# Cálculo de Aŕea mínima

A_min=((I_Falla/1000)*Kf*m.sqrt(Tc/1000))/1.974

if A_min < 67.45:
    calibre = "2/0 AWG"
elif 67.45 <= A_min<107.23:
    calibre ="4/0 AWG"
elif 107.23 <= A_min<126.69:
    calibre = "250 kcmil"
elif 126.69 <= A_min<152.02:
    calibre ="300 kcmil"
else:
    calibre="350 kcmil"

if calibre =="2/0 AWG":
    diam = 0.0093
elif calibre == "4/0 AWG":
    diam = 0.0117
elif calibre == "250 kcmil":
    diam = 0.0127
elif calibre == "300 kcmil":
    diam = 0.0139
elif calibre == "350 kcmil":
    diam = 0.015
else:
    print("Error al elegir el diámetro")


borrarPantalla()
print (" \n")
print ("*************************************************************************\n" )
print("SELECCIONE LA GEOMETRÍA DE LA MALLA:")
print ("*************************************************************************\n")
print("---------------------------------------------------------------------------")
print("1) Geometría Cuadrada  ")
print("2) Geometría Retangular")
print("3) Geometría en forma de 'L'")
flag4 = int(input("Número Geometría seleccionada = "))

if flag4==1:
    borrarPantalla()
    tipomalla = f" Geometría Cuadrada "
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("DIMENSIONES MALLA GEOMETRÍA CUADRADA")
    print ("*************************************************************************\n" )
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("INGRESE LA LONGITUD DEL LADO DE LA MALLA:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    largo = float(input("Longiud [m] = "))
    ancho=largo
    # L1, l2, es una característica de las mallas en forma de 'L'
    l1=0
    l2=0
elif flag4==2:
    tipomalla = f" Geometría Rectangular"
    borrarPantalla()
    print (" \n")
    print ("*************************************************************************\n")
    print("DIMENSIONES MALLA GEOMETRÍA RECTANGULAR")
    print ("*************************************************************************\n")
    print (" \n" )
    print ("*************************************************************************\n")
    print("INGRESE LADO DE MAYOR LONGITUD [m]:")
    print ("*************************************************************************\n")
    print("---------------------------------------------------------------------------")
    largo=float(input("Largo[m] = : "))
    print (" \n")
    print ("*************************************************************************\n")
    print("INGRESE LADO DE MENOR LONGITU[m] =")
    print ("*************************************************************************\n")
    print("---------------------------------------------------------------------------")
    ancho=float(input("Ancho[m] = "))
    l1=0
    l2=0
elif flag4==3:
    tipomalla = f" Geometría en forma de 'L'"
    borrarPantalla()
    print("    *******l1******     ")
    print("   L*             *     ")
    print("   A*             *     ")
    print("   R*             *     ")
    print("   G*             *     ")
    print("   O*             *     ")
    print("    *             **************    ")
    print("    *                          *    ")
    print("    *                          * L2 ")
    print("    *                          *    ")
    print("    ***********ANCHO************    ")
    print (" \n")
    print ("*************************************************************************\n" )
    print("DIMENSIONES MALLA GEOMETRÍA EN 'L'")
    print ("*************************************************************************\n" )
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO DE MAYOR LONGITUD DE LA 'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    largo=float(input("Largo[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO DE MENOR LONGITUD DE LA 'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    ancho=float(input("Ancho[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO L1 DE LA'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    l1=float(input("L1[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO L2 DE LA'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    l2=float(input("L2 =  "))
borrarPantalla()
# La cuadrícula es las subdivision de los lados de la malla
print (" \n")
print ("*************************************************************************\n" )
print("INGRESE LONGITUD DEL LADO DE LA CUADRÍCULA DE LA MALLA[cm]:")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
lado_cuadri = float(input("Longitud cuadrícula[cm] = "))

if flag4==1 or flag4==2:

    longi_conduc_horiz=((largo/(lado_cuadri/100))+1)*ancho+((ancho/(lado_cuadri/100))+1)*largo
elif flag4==3:
    longi_conduc_horiz=((largo/(lado_cuadri/100))+1)*l1+((l1/(lado_cuadri/100))+1)*largo+(((ancho-l1)/(lado_cuadri/100)))*l2+((l2/(lado_cuadri/100))+1)*(ancho-l1)

borrarPantalla()
print (" \n")
print ("*************************************************************************\n" )
print("EL DISEÑO PRELIMINAR TIENE VARILLAS?")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
print("1) Si tiene varillas  ")
print("2) No tiene varillas")
print("---------------------------------------------------------------------------")
flag=int(input())

if flag==1:

    borrarPantalla()
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LA LONGITUD DE LAS VARILLAS[cm]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    longi_vari=int(input("Longitud Varillas[cm] = "))


    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE EL NÚMERO DE VARILLAS")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    num_vari=int(input("Cantidad de varillas = "))

    longi_total_vari=num_vari*longi_vari/100

elif flag==2:

    num_var=0
    longi_vari=0
    longi_total_vari=0
else:

    print("Ingresó una opción inválida")
# Longitud de las varillas según para el diseño preliminar
longi_perim = 2*(largo+ancho)


borrarPantalla()
print (" \n" )
print ("*************************************************************************\n" )
print("INGRESE LA PROFUNDIDAD DE ENTERRAMIENTO DE LA MALLA[cm]")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
prof_enterra = int(input("Profundidad[cm] = "))

if flag4==1 or flag4==2:
    area_malla=largo*ancho
elif flag4==3:
    area_malla = (largo*l1)+l2*(ancho-l1)
else:
    print("Error")
borrarPantalla()
print (" \n" * (2))
print ("*************************************************************************\n" )
print("INGRESE PESO APROXIMADO DE UNA PERSONA SOBRE LA MALLA")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
print("1) 50KG  ")
print("2) 70KG")
flag5 = int(input("Número de peso seleccionado = "))

# Tensiones de paso y de contacto
Cs = 1-(0.09*(1-(resisti_apare/resisti))/((2*hs/100)+0.09))

if flag5==1:
    t_contac_tolerable=(1000+1.5*Cs*resisti)*0.116/m.sqrt(Tc/1000)
    t_paso_tolerable=(1000+6*Cs*resisti)*0.116/m.sqrt(Tc/1000)
elif flag5==2:
    t_contac_tolerable=(1000+1.5*Cs*resisti)*0.157/m.sqrt(Tc/1000)
    t_paso_tolerable=(1000+6*Cs*resisti)*0.157/m.sqrt(Tc/1000)
else:
    print("No seleccionó una opción válida")

t_contac_tolerable50=(1000+1.5*Cs*resisti)*0.116/m.sqrt(Tc/1000)
t_paso_tolerable50=(1000+6*Cs*resisti)*0.116/m.sqrt(Tc/1000)

t_contac_tolerable70=(1000+1.5*Cs*resisti)*0.157/m.sqrt(Tc/1000)
t_paso_tolerable70=(1000+6*Cs*resisti)*0.157/m.sqrt(Tc/1000)

# Resistencias de puesta a tierra

res_puesta_tierra=resisti_apare*((1/(longi_conduc_horiz+longi_total_vari))+(1/m.sqrt(20*area_malla))*(1+(1/(1+prof_enterra*m.sqrt(20/area_malla)/100))))

# Cálculo de la tensión de la malla

C45=2*longi_conduc_horiz/longi_perim
D45=m.sqrt(longi_perim/(4*m.sqrt(area_malla)))

if flag4==1 or flag4==2:
    E45=1
elif flag4==3:
    E45=(largo*ancho/area_malla)**(0.7*area_malla/(largo*ancho))

else:
    print("Error en el ingreso de datos")

n=C45*D45*E45# n

if flag==1:
    H45=1
elif flag==2:
    H45=1/(2*n)**(2/n)


G45=m.sqrt(1+0.01*prof_enterra)


ki=0.644+0.148*n # ki


ks=(1/m.pi)*((1/(2*prof_enterra/100))+(1/((lado_cuadri/100)+(prof_enterra/100)))+(100/lado_cuadri)*(1-0.5**(n-2)))


km = (1/(2*m.pi))*(m.log1p((((lado_cuadri*0.01)**2)/(16*prof_enterra*0.01*diam))+(((lado_cuadri*0.01+2*0.01*prof_enterra)**2)/(8*lado_cuadri*0.01*diam))-((prof_enterra*0.01)/(4*diam))-1)+((H45/G45)*m.log1p(8/(m.pi*((2*n)-1))-1)))
# Se calcula la máxima corriente de malla
# 0,6 ; I03 datos de la subestación del diseño
IG = (1)*(Sf)*(I03)
##print("Resitividad = ",resisti_apare)
##print("n = ",n)
##print(" km = ",km)
##print(" ks = ",ks)
##print(" ki = ",ki)
##print("Longitud total =",longi_conduc_horiz)
##print("IG =",IG)
##input()
# GPR
GPR = round(IG) * round(res_puesta_tierra,2)

Em =(resisti_apare*IG*km*ki)/(longi_conduc_horiz+(1.55+1.22*(longi_vari*0.01/(m.sqrt(largo**2+ancho**2))))*longi_total_vari)

Es =(resisti_apare*IG*ks*ki)/(0.75*longi_conduc_horiz+0.85*longi_total_vari)
borrarPantalla()

print (" \n")
print ("*************************************************************************\n")
print("DATOS DISEÑO PRELIMINAR:")
print ("*************************************************************************\n")
print(f'''
Diseño de malla de puesta a tierra {tipomalla }
________________________________________________________________________________
Resistencia objetivo menor = {res_menor}[Ohm]
________________________________________________________________________________
Resistividad aparente del terreno = {resisti_apare}[Ohm_m]
________________________________________________________________________________
Corriente de falla trifasica a tierra en el primario = {I_Falla}[A]
________________________________________________________________________________
Tiempo de despeje de la malla  = {Tc}[ms]
________________________________________________________________________________
Material del conductor: {M}[40°C]
________________________________________________________________________________
Resisitividad capa superficial = {resisti} [Ohm_m]
________________________________________________________________________________
Diámetro del conductor = {diam}[mm]      Calibre sugerido: {calibre}
________________________________________________________________________________
Longitud conductor horizontal = {longi_conduc_horiz}[m]
________________________________________________________________________________
Longitud total de varillas = {longi_total_vari}[m]
________________________________________________________________________________
Longitud total del perímetro = {longi_perim}[m]
________________________________________________________________________________
Área de la malla = {area_malla}[m^2]
_______________________________________________________________________________
Tensión de paso 50kg = {round(t_paso_tolerable50,3)} [V]
_______________________________________________________________________________
Tensión de contacto 50kg = {round(t_contac_tolerable50,3)} [V]
________________________________________________________________________________
Tensión de paso 70kg = {round(t_paso_tolerable70,3)} [V]

Tensión de contacto 70kg = {round(t_contac_tolerable70,3)} [V]
________________________________________________________________________________

Resistencia de puesta a tierra = {round(res_puesta_tierra,2)}[Ohms]
_______________________________________________________________________________
Máxima corriente de malla  {round(IG)} [A]     GPR = {GPR}[V]
_______________________________________________________________________________

Tensión de malla Em = {Em} [V]     Enter para continuar...
_______________________________________________________________________________

''')
input()

borrarPantalla()
if GPR > t_contac_tolerable:

    com1 = "El GPR"
    com2 = "el voltaje de contacto tolerable"
    d1 = 0
else:

    com1 = "El voltaje de contacto tolerable"
    com2 = "GPR"
    d1 = 1

if Em > t_contac_tolerable:

    com3 = "El Voltaje de malla"
    com4 = "el voltaje de contacto tolerable"
    d2 = 0
else:

    com3 = "El voltaje de contacto tolerable "
    com4 = "el Voltaje de malla"
    d2 = 1

if Es > t_paso_tolerable:

    com5 = "El Voltaje de paso calculado"
    com6 = "el voltaje de paso tolerable"
    d3 = 0
else:

    com5 = "El voltaje de paso tolerable"
    com6 = "el Voltaje de paso calculado"
    nota1 ="Se cumple con la resistencia mínima sugerida"
    d3 = 1

if res_puesta_tierra > res_menor:

    com7 = "La resistencia calculada"
    com8 = "la mínima reistencia sugerida por el RETIE"
    nota1 = f'''
    Si no es posible obtener una resistencia de puesta a tierra por debajo
    de los límites sugeridos por el RETIE, se puede continuar con la constr-
    ucción  de la malla, siempre y cuando se cumpla con los criterios
    de tensión de contacto y de paso mínimos tolerables.
    '''
    d4 = 0
else:

    com7 = "La mínima reistencia sugerida RETIE"
    com8 = "la resistencia calculada"
    d4 = 1

n = d2*d3

if n == 0:
    diag = "Modigique su diseño"
else:
    diag = "Diseño exitoso! "

borrarPantalla()
print (" \n")
print(f'''

********************************************************************************
ANÁLISI COMPARATIVO
********************************************************************************
GPR = {GPR}
-------------------------------------------------------------------------------
Voltaje de contacto tolerable  = {round(t_contac_tolerable,3)}[V]

Voltaje de malla  = {round(Em,3)}[V]

{com3} es mayor que {com4}
-------------------------------------------------------------------------------

Vpaso tolerable = {round(t_paso_tolerable,3)}[V]

Vpaso caculado =  {round(Es,3)} [V]

{com5} es mayor que {com6}
-------------------------------------------------------------------------------

Resistencia de puesta a tierra sugerida =  {res_menor}[Ohms]

Resistencia de puesta tierra malla =  {round(res_puesta_tierra,2)}[Ohms]

{com7} es mayor que {com8}

Nota : {nota1}
-------------------------------------------------------------------------------
Diagnóstico : {diag}
_______________________________________________________________________________

''')
"""
Se calculael numero de cruces en forma de X,L y T
"""
input()
if flag4==1 or flag4==2:
    lado_cuadri_m=lado_cuadri/100
    nL=4
    nx=((largo/lado_cuadri_m)-1)*((ancho/lado_cuadri_m)-1)
    nT=(((largo/lado_cuadri_m)-1)+((ancho/lado_cuadri_m)-1))*2
    forma=("Rectangular")
elif flag4==3:
    nL=5
    lado_cuadri_m=lado_cuadri/100
    nx=1+((largo/lado_cuadri_m)-1)*((l1/lado_cuadri_m)-1)+((l2/lado_cuadri_m)-1)*((ancho-l1)/lado_cuadri_m)
    nT=((2*(ancho+largo))/lado_cuadri_m)-6
    forma=("forma L")
"""
Añadimos un diccionario con la cantidad de soldadura por calibre

"""

LibreriaT={
   "2/0 AWG":90 ,
   "4/0 AWG":150 ,
   "250 kcmil":150 ,
   "300 kcmil":200 ,
   "350 kcmil":200
   }
LibreriaX={
   "2/0 AWG":115 ,
   "4/0 AWG":200 ,
   "250 kcmil":200 ,
   "300 kcmil":250 ,
   "350 kcmil":250
   }
LibreriaL={
   "2/0 AWG":90 ,
   "4/0 AWG":150 ,
   "250 kcmil":150 ,
   "300 kcmil":200 ,
   "350 kcmil":200
   }
PrecioSoldadura={
    90: 13800,
    115:16800,
    150:21900,
    200:26200,
    250:32550,
   }
PrecioCobreDuro={
   "2/0 AWG":43200 ,
   "4/0 AWG":67200 ,
   "250 kcmil":80150 ,
   "300 kcmil":95000 ,
   "350 kcmil":112250
   }
SoldaduraT=LibreriaT[calibre]
SoldaduraL=LibreriaL[calibre]
SoldaduraX=LibreriaX[calibre]
PrecioT=PrecioSoldadura[SoldaduraT]
PrecioL=PrecioSoldadura[SoldaduraL]
PrecioX=PrecioSoldadura[SoldaduraX]
PrecioCobre=PrecioCobreDuro[calibre]
print(f'''

********************************************************************************
CANTIDAD DE CRUCES EN EL CIRCUITO
********************************************************************************
La malla tiene forma {forma}
-------------------------------------------------------------------------------

Numero de cruces L:{nL}
Soldadura por cruce : {SoldaduraL} gr
Precio Unitario:{PrecioL}
Precio total soldadura .exo L:{PrecioL*nL} COP

-------------------------------------------------------------------------------

Numero de cruces T:{nT}
Soldadura por cruce : {SoldaduraT} gr
Precio Unitario:{PrecioT}
Precio total soldadura .exo T:{PrecioT*nT} COP

-------------------------------------------------------------------------------

Numero de cruces X:{nx}
Soldadura por cruce : {SoldaduraX} gr
Precio Unitario:{PrecioX}
Precio total soldadura .exo L:{PrecioX*nx} COP

-------------------------------------------------------------------------------

PRECIO TOTAL POR SOLDADURA EXOTERMICA: {PrecioX*nx+PrecioT*nT+PrecioL*nL} COP

-------------------------------------------------------------------------------
El total de longitud total de la malla :{round(longi_conduc_horiz)}  [m]

De un calibre minimo sugerido de {calibre}
_______________________________________________________________________________

''')

input()


if flag==1:
    print(f'''

********************************************************************************
Varillas
********************************************************************************
El numero de varillas son {num_vari} , de una longitud {longi_vari} [cm]

Para una longitud total entre varillas y malla de :{round(longi_conduc_horiz)+longi_vari*0.01} [m]
El precio por metro es   :{PrecioCobre} COP
Precio total de longitud :{(round(longi_conduc_horiz)+longi_vari)*PrecioCobre} COP
_______________________________________________________________________________

''')


"""
Se realiza el dibujo de la malla de puesta a tierra
"""
if flag4==1 or flag4==2:
    lado_cuadri_m=lado_cuadri/100
    n_largo=int((largo/lado_cuadri_m)+1)
    n_ancho=int((ancho/lado_cuadri_m)+1)

    x,y=np.linspace(0,ancho,n_ancho),np.linspace(0,largo,n_largo)
    # Valores de x, y para cuadrícula de la malla
    X,Y=np.meshgrid(x,y)
    # Ecuación zn = f(x,y)
    Z1=Y


    fig=plt.figure()
    ax=fig.add_subplot(projection='3d')
    # alpha da la tranparencia a la superficie
    #ax.plot_surface(X,Y,Z1,alpha=0.9,cmap=cm.Accent,rstride=100,cstride=100)
    ax.plot_wireframe(X,Y,Z1,alpha=1,rstride=1,cstride=1)
    #ax.plot_surface(X,Y,Z2,alpha= 0.9,cmap=cm.Paired,rstride=100,cstride=100)
    #ax.plot_surface(X,Y,Z3,alpha=0.9,cmap=cm.Pastel1,rstride=100,cstride=100)
    plt.title("Malla")
    plt.show()
elif flag4==3:

    lado_cuadri_m=lado_cuadri/100
    n_largo=int((largo/lado_cuadri_m)+1)
    n_ancho=int((l1/lado_cuadri_m)+1)
    n_xmalla2=int(((ancho-l1)/lado_cuadri_m)+1)
    n_ymalla2=int(((l2)/lado_cuadri_m)+1)

    x,y=np.linspace(0,l1,n_ancho),np.linspace(0,largo,n_largo)
    x2,y2=np.linspace(l1,ancho,n_xmalla2),np.linspace(0,l2,n_ymalla2)
    # Valores de x, y para cuadrícula de la malla
    X,Y=np.meshgrid(x,y)
    # Ecuación zn = f(x,y)
    X2,Y2=np.meshgrid(x2,y2)
    Z1=Y
    Z2=Y2
    fig=plt.figure()
    ax=fig.add_subplot(projection='3d')
    # alpha da la tranparencia a la superficie
    #ax.plot_surface(X,Y,Z1,alpha=0.9,cmap=cm.Accent,rstride=100,cstride=100)
    ax.plot_wireframe(X,Y,Z1,alpha=1,rstride=1,cstride=1)
    ax.plot_wireframe(X2,Y2,Z2,alpha=1,rstride=1,cstride=1)
# Out:
# ¿Desea ejecutar un programa para  STP tipo poste? (s/n): n
# *************************************************************************
#
# DISEÑO DE MALLA DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR, CUADRADA
# Y EN FORMA DE 'L' SEGÚN NORMA IEEE-80/2000
# V2022_1
# ELABORADO POR: MARIO LEÓN HOYOS LONDOÑO
# MAYO DE 2022
# EMPRESA ENERVOLT S.A.S.
# *************************************************************************
#
# *************************************************************************
#
# SELECCIONE EL NÚMERO CORRESPONDIENTE AL TIPO DE SUBESTACIÓN:
# -------------------------------------------------------------------------
#
# 1) Subestaciones de alta y extra alta tensión
# 2) Subestaciones de media tensión en poste
# 3) Subestaciones de media tensión de uso interior
#  Número tipo de subestación = 3
#
#
# *************************************************************************
#
# INGRESE EL VALOR DE LA RESISTIVIDAD APARENTE DEL TERRENO HOMOGENEO
# ...

# %%
#PROGRAMA PARA DISEÑO DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR
import math as m
import os
import platform
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

def borrarPantalla():

    '''
    La función borrar pantalla,funciona cuando el programa se ejecuta desde una
    terminal. Si el programa se ejecuta desde el IDLE de python, esta función no
    será reconocida por el programa, ya que el IDLE no es una terminal de sis-
    tema operativo, sino un programa hecho en  Python Tekinter.

    '''
##
##    if platform.system() == "Linux":
##
##       os.system("clear")
##
##    else:
##
##       os.system("clS")

#-------------------------------------------------------------------------------------
##$borrarPantalla()
#print ("\n" * (4))
#graficas


def plot_circle_with_points(r_exterior, r_interior, angle1, angle2):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior*1.1)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()





def plot_circle_with_points1(r_exterior, r_interior, angle1, angle2, angle3):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior*1.1)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()





def plot_circle_with_points2(r_exterior, r_interior, angle1, angle2, angle3,angle4 ):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior*1.1)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()





def plot_circle_with_points3(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+3)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()



def plot_circle_with_points4(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+3.5)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()


def plot_circle_with_points5(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+3.5], 'g',label="l = 5m")
    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde adicional desde (1.5, 90) de radio
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+5], 'g',label="l = 5m")


    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+3.5)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()


def plot_circle_with_points6(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior], 'r')

    # Dibujar la línea verde
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+5], 'g',label="l = 5m")
    # Dibujar la línea verde adicional desde (1.5, 90) de radio
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+5], 'g',label="l = 5m")
    ax.plot([np.deg2rad(270), np.deg2rad(270)], [r_exterior, r_exterior+5], 'g',label="l = 5m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+5)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.show()


def plot_circle_with_points7(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+10], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()



def plot_circle_with_points8(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+8.5], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+10], 'g')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()



def plot_circle_with_points9(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+8.5], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+10], 'g')
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+ 10], 'g')


    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()



def plot_circle_with_points10(r_exterior, r_interior, angle1, angle2, angle3, angle4):
    # Definir las coordenadas polares para el círculo exterior
    theta = np.linspace(0, 2*np.pi, 100)

    # Crear la figura y los ejes
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)

    # Dibujar el círculo exterior
    ax.plot(theta, np.ones_like(theta)*r_exterior, 'b')

    # Dibujar el círculo interior
    ax.plot(theta, np.ones_like(theta)*r_interior, 'b')

    # Dibujar el radio de 1.5 metros con ángulo de cero
    ax.plot([0, 0], [0, r_exterior+10], 'r')

    # Dibujar la línea verde
    ax.plot([0, np.deg2rad(0)], [r_exterior, r_exterior+10], 'g', label="l = 10 m")
    ax.plot([np.deg2rad(180), np.deg2rad(180)], [r_exterior, r_exterior+10], 'g')
    ax.plot([np.deg2rad(90), np.deg2rad(90)], [1.5, 1.5+ 10], 'g')
    ax.plot([np.deg2rad(270), np.deg2rad(270)], [r_exterior, r_exterior+10], 'g')

    # Agregar punto rojo en coordenadas (r_exterior, angle1)
    ax.plot(np.deg2rad(angle1), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle2), r_exterior, 'ro')

    # Agregar punto rojo en coordenadas (r_exterior, angle2)
    ax.plot(np.deg2rad(angle3), r_exterior, 'ro')
    ax.plot(np.deg2rad(angle4), r_exterior, 'ro')

    # Establecer los límites y etiquetas de los ejes
    ax.set_ylim(0, r_exterior+10)
    ax.set_yticks([r_interior, r_exterior])
    ax.set_yticklabels([f"{r_interior}m", f"{r_exterior}m"])

    # Mostrar la gráfica
    plt.legend(loc='upper right')
    plt.show()

respuesta = input("¿Desea ejecutar un programa para  STP tipo poste? (s/n): ")
if respuesta == "s":


    radii = [0.9, 1.5]
    theta = np.linspace(0, 2*np.pi, 100)
    resistividad = 0
    while resistividad < 100 or resistividad > 1400:
        resistividad = int(input("Ingrese la resistividad del terreno en ohm-metros (entre 100 y 1400): "))
        if resistividad >= 100 and resistividad <= 200:
            plot_circle_with_points(1.5, 0.9, 180, 90)
        elif resistividad > 200 and resistividad <= 300:
            plot_circle_with_points1(1.5, 0.9, 180, 90, 0)
        elif resistividad > 300 and resistividad <= 400:
            plot_circle_with_points2(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 400 and resistividad <= 500:
            plot_circle_with_points3(1.5, 0.9, 180, 90, 0, 270)
        elif  resistividad > 500 and resistividad <= 600:
            plot_circle_with_points4(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 600 and resistividad <= 700:
            plot_circle_with_points5(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 700 and resistividad <= 800:
            plot_circle_with_points6(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 800 and resistividad <= 900:
            plot_circle_with_points7(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 900 and resistividad <= 1000:
            plot_circle_with_points8(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 1000 and resistividad <= 1100:
            plot_circle_with_points9(1.5, 0.9, 180, 90, 0, 270)
        elif resistividad > 1100 and resistividad <= 1400:
            plot_circle_with_points10(1.5, 0.9, 180, 90, 0, 270)

    # Preguntar al usuario si desea imprimir las consideraciones
    imprimir_consideraciones = input("¿Desea imprimir las consideraciones? (Sí/No): ")

    # Verificar si el usuario quiere imprimir las consideraciones
    if imprimir_consideraciones.lower() == "sí":
        # Imprimir las consideraciones
        print("Consideraciones:")
        print("• Círculo interno R1: 0,9 m desde la base del poste.")
        print("• Círculo externo R2: 1,5 metros desde la base del poste.")
        print("• L: corresponde a la longitud del contrapeso a utilizar.")
        print("• El cable o bajante de puesta a tierra se debe empalmar con el círculo interno (R1) así como con la varilla más próxima al punto donde se entierre.")
        print("• Los círculos internos (R1) y externo (R2) se deben empalmar en por lo menos dos puntos (separados 180°) por medio de soldadura exotérmica. La conexión se debe realizar para evitar la concentración de potenciales en el SPT.")
        print("• Para resistividades superiores a 2000 Ω-m se debe emplear la configuración No 11.")
    else:
        print("No se imprimirán consideraciones.")




print ("*************************************************************************\n")
print("DISEÑO DE MALLA DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR, CUADRADA ")
print("Y EN FORMA DE 'L' SEGÚN NORMA IEEE-80/2000")
print("V2022_1")
print("ELABORADO POR: MARIO LEÓN HOYOS LONDOÑO")
print("MAYO DE 2022")
print("EMPRESA ENERVOLT S.A.S.")
print ("*************************************************************************\n")
#print("NOTA: Luego de ingresar información  'ENTER' para confimar y continuar.")
#print ("-------------------------------------------------------------------------\n" * (1))
#input()
#-----------------------------------------------------------------------------------------
#borrarPantalla()
##print ("\n" * (1))
print ("*************************************************************************\n")
print("SELECCIONE EL NÚMERO CORRESPONDIENTE AL TIPO DE SUBESTACIÓN:")
print ("-------------------------------------------------------------------------\n")
print("1) Subestaciones de alta y extra alta tensión  ")
print("2) Subestaciones de media tensión en poste ")
print("3) Subestaciones de media tensión de uso interior ")
flag1 =  int(input(" Número tipo de subestación = "))

while True:
    if flag1==1:
        res_menor = 1
        break

    elif flag1==2:

        res_menor = 10
        break
    elif flag1==3:

        res_menor = 5
        break

resisti_apare=9
while resisti_apare < 10 or resisti_apare > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n" )
        print("INGRESE EL VALOR DE LA RESISTIVIDAD APARENTE DEL TERRENO HOMOGENEO")
        print ("*************************************************************************\n" )
        print("     ")
        print("---------------------------------------------------------------------------")
        resisti_apare= float(input("Resitivad aparente [Ohm_m] = "))
        print("---------------------------------------------------------------------------")

I_Falla=99
while I_Falla < 100 or I_Falla > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n")
        print("INGRESE CORRIENTE LA DE FALLA DE SECUENCIA CERO EN EL SECUNDARIO DE LA S/E 3I0s")
        print ("*************************************************************************\n")
        print("100A < IF < 20.000A ")
        print("---------------------------------------------------------------------------")
        I_Falla =  float(input("Corriente de falla 1F [A] = "))
I_Falla1=99
while I_Falla1 < 100 or I_Falla1 > 20000:
        borrarPantalla()
        print (" \n" * (1))
        print ("*************************************************************************\n")
        print("INGRESE CORRIENTE DE FALLA DE SECUENCIA CERO EN EL PRIMARIO DE LA S/E 3I0p")
        print ("*************************************************************************\n" )
        print("100A < IF < 20.000A ")
        print("---------------------------------------------------------------------------")
        I_Falla1 =  float(input("Corriente de falla 1F [A] = "))

I03 = I_Falla1

borrarPantalla()
print (" \n" )
print ("*************************************************************************\n")
print("INGRESE EL FACTOR DIVISOR DE CORRIENTE DE FALLA Sf DE LA SUBESTACIÓN")
print ("*************************************************************************\n")
print("---------------------------------------------------------------------------")
Sf = float(input("Division de corriente de falla Sf = "))

Tc=49
while Tc < 50 or Tc > 500:
        borrarPantalla()
        print (" \n")
        print ("*************************************************************************\n")
        print("INGRESE TIEMPO DE  DESPEJE DE FALLA EN [ms]")
        print ("*************************************************************************\n" )
        print("50ms < t < 500ms ")
        print("---------------------------------------------------------------------------")
        Tc = float(input(" Tiempo de despeje de falla[ms] = "))

borrarPantalla()
print (" \n" * (1))
print ("*************************************************************************\n" )
print("SELECCIONE EL TIPO DE MATERIAL UTILIZADO PARA LA  PUESTA  TIERRA:")
print ("*************************************************************************\n" )
print("1) Cobre blando  ")
print("2) Cobre duro. Cuando se utiliza soldadura exotérmica")
print("3) Cobre duro. Cuando se utilizan conexiones mecánicas a presión ")
print("4) Alambre de acero recubierto de cobre  ")
print("5) Varilla de acero recubierta de cobre ")
print("6) Varilla de acero galvanizada ")
print("Temperatura 40° ")
print("---------------------------------------------------------------------------")
flag2= int(input("Número material seleccionado = "))

if flag2==1:
    Kf=7
    M = "1) Cobre blando  "
elif flag2==2:
    Kf=7.06
    M = "Cobre duro cuando se utiliza soldadura exotérmica"
elif flag2==3:
    Kf=11.78
    M = "Cobre duro cuando se utilizan conexiones mecánicas a presión "
elif flag2==4:
    Kf=10.45
    M = "Alambre de acero recubierto de cobre"
elif flag2==5:
    Kf=14.64
    M = "Varilla de acero recubierta de cobre "
elif flag2==6:
    Kf=14.72
    M = "Varilla de acero galvanizada "
else:
    print("No ingresó un dato correcto")
borrarPantalla()
print (" \n" * (1))
print ("*************************************************************************\n" )
print("SELECCIONE INFORMACIÓN SOBRE CAPA SUPERFICIAL:")
print ("*************************************************************************\n" )
print("1) Si hay capa superficial ")
print("2) No hay capa superficial")
print("---------------------------------------------------------------------------")
flag3 = int(input("Capa suerficial[Si=1, No =2] = "))

if flag3==1:
    borrarPantalla()
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("INGRESE VALOR DE RESISTIVIDAD DE LA CAPA SUPERFICIAL en[Ohm_m]:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    resisti = float(input("Resistividad Capa superficial [Ohm_m] = "))

    print (" \n" )
    print ("*************************************************************************\n")
    print("INGRESE ESPESOR DE LA CAPA SUPERFICIAL en[cm]:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    hs = float(input("Espesor =  "))

elif flag3==2:
    resisti=resisti_apare
    hs=0
else:
    print("No ingresó un dato correcto")
# Cálculo de Aŕea mínima

A_min=((I_Falla/1000)*Kf*m.sqrt(Tc/1000))/1.974

if A_min < 67.45:
    calibre = "2/0 AWG"
elif 67.45 <= A_min<107.23:
    calibre ="4/0 AWG"
elif 107.23 <= A_min<126.69:
    calibre = "250 kcmil"
elif 126.69 <= A_min<152.02:
    calibre ="300 kcmil"
else:
    calibre="350 kcmil"

if calibre =="2/0 AWG":
    diam = 0.0093
elif calibre == "4/0 AWG":
    diam = 0.0117
elif calibre == "250 kcmil":
    diam = 0.0127
elif calibre == "300 kcmil":
    diam = 0.0139
elif calibre == "350 kcmil":
    diam = 0.015
else:
    print("Error al elegir el diámetro")


borrarPantalla()
print (" \n")
print ("*************************************************************************\n" )
print("SELECCIONE LA GEOMETRÍA DE LA MALLA:")
print ("*************************************************************************\n")
print("---------------------------------------------------------------------------")
print("1) Geometría Cuadrada  ")
print("2) Geometría Retangular")
print("3) Geometría en forma de 'L'")
flag4 = int(input("Número Geometría seleccionada = "))

if flag4==1:
    borrarPantalla()
    tipomalla = f" Geometría Cuadrada "
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("DIMENSIONES MALLA GEOMETRÍA CUADRADA")
    print ("*************************************************************************\n" )
    print (" \n" * (1))
    print ("*************************************************************************\n" )
    print("INGRESE LA LONGITUD DEL LADO DE LA MALLA:")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    largo = float(input("Longiud [m] = "))
    ancho=largo
    # L1, l2, es una característica de las mallas en forma de 'L'
    l1=0
    l2=0
elif flag4==2:
    tipomalla = f" Geometría Rectangular"
    borrarPantalla()
    print (" \n")
    print ("*************************************************************************\n")
    print("DIMENSIONES MALLA GEOMETRÍA RECTANGULAR")
    print ("*************************************************************************\n")
    print (" \n" )
    print ("*************************************************************************\n")
    print("INGRESE LADO DE MAYOR LONGITUD [m]:")
    print ("*************************************************************************\n")
    print("---------------------------------------------------------------------------")
    largo=float(input("Largo[m] = : "))
    print (" \n")
    print ("*************************************************************************\n")
    print("INGRESE LADO DE MENOR LONGITU[m] =")
    print ("*************************************************************************\n")
    print("---------------------------------------------------------------------------")
    ancho=float(input("Ancho[m] = "))
    l1=0
    l2=0
elif flag4==3:
    tipomalla = f" Geometría en forma de 'L'"
    borrarPantalla()
    print("    *******l1******     ")
    print("   L*             *     ")
    print("   A*             *     ")
    print("   R*             *     ")
    print("   G*             *     ")
    print("   O*             *     ")
    print("    *             **************    ")
    print("    *                          *    ")
    print("    *                          * L2 ")
    print("    *                          *    ")
    print("    ***********ANCHO************    ")
    print (" \n")
    print ("*************************************************************************\n" )
    print("DIMENSIONES MALLA GEOMETRÍA EN 'L'")
    print ("*************************************************************************\n" )
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO DE MAYOR LONGITUD DE LA 'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    largo=float(input("Largo[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO DE MENOR LONGITUD DE LA 'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    ancho=float(input("Ancho[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO L1 DE LA'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    l1=float(input("L1[m] = "))
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LADO L2 DE LA'L'[m]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    l2=float(input("L2 =  "))
borrarPantalla()
# La cuadrícula es las subdivision de los lados de la malla
print (" \n")
print ("*************************************************************************\n" )
print("INGRESE LONGITUD DEL LADO DE LA CUADRÍCULA DE LA MALLA[cm]:")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
lado_cuadri = float(input("Longitud cuadrícula[cm] = "))

if flag4==1 or flag4==2:

    longi_conduc_horiz=((largo/(lado_cuadri/100))+1)*ancho+((ancho/(lado_cuadri/100))+1)*largo
elif flag4==3:
    longi_conduc_horiz=((largo/(lado_cuadri/100))+1)*l1+((l1/(lado_cuadri/100))+1)*largo+(((ancho-l1)/(lado_cuadri/100)))*l2+((l2/(lado_cuadri/100))+1)*(ancho-l1)

borrarPantalla()
print (" \n")
print ("*************************************************************************\n" )
print("EL DISEÑO PRELIMINAR TIENE VARILLAS?")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
print("1) Si tiene varillas  ")
print("2) No tiene varillas")
print("---------------------------------------------------------------------------")
flag=int(input())

if flag==1:

    borrarPantalla()
    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE LA LONGITUD DE LAS VARILLAS[cm]")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    longi_vari=int(input("Longitud Varillas[cm] = "))


    print (" \n" )
    print ("*************************************************************************\n" )
    print("INGRESE EL NÚMERO DE VARILLAS")
    print ("*************************************************************************\n" )
    print("---------------------------------------------------------------------------")
    num_vari=int(input("Cantidad de varillas = "))

    longi_total_vari=num_vari*longi_vari/100

elif flag==2:

    num_var=0
    longi_vari=0
    longi_total_vari=0
else:

    print("Ingresó una opción inválida")
# Longitud de las varillas según para el diseño preliminar
longi_perim = 2*(largo+ancho)


borrarPantalla()
print (" \n" )
print ("*************************************************************************\n" )
print("INGRESE LA PROFUNDIDAD DE ENTERRAMIENTO DE LA MALLA[cm]")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
prof_enterra = int(input("Profundidad[cm] = "))

if flag4==1 or flag4==2:
    area_malla=largo*ancho
elif flag4==3:
    area_malla = (largo*l1)+l2*(ancho-l1)
else:
    print("Error")
borrarPantalla()
print (" \n" * (2))
print ("*************************************************************************\n" )
print("INGRESE PESO APROXIMADO DE UNA PERSONA SOBRE LA MALLA")
print ("*************************************************************************\n" )
print("---------------------------------------------------------------------------")
print("1) 50KG  ")
print("2) 70KG")
flag5 = int(input("Número de peso seleccionado = "))

# Tensiones de paso y de contacto
Cs = 1-(0.09*(1-(resisti_apare/resisti))/((2*hs/100)+0.09))

if flag5==1:
    t_contac_tolerable=(1000+1.5*Cs*resisti)*0.116/m.sqrt(Tc/1000)
    t_paso_tolerable=(1000+6*Cs*resisti)*0.116/m.sqrt(Tc/1000)
elif flag5==2:
    t_contac_tolerable=(1000+1.5*Cs*resisti)*0.157/m.sqrt(Tc/1000)
    t_paso_tolerable=(1000+6*Cs*resisti)*0.157/m.sqrt(Tc/1000)
else:
    print("No seleccionó una opción válida")

t_contac_tolerable50=(1000+1.5*Cs*resisti)*0.116/m.sqrt(Tc/1000)
t_paso_tolerable50=(1000+6*Cs*resisti)*0.116/m.sqrt(Tc/1000)

t_contac_tolerable70=(1000+1.5*Cs*resisti)*0.157/m.sqrt(Tc/1000)
t_paso_tolerable70=(1000+6*Cs*resisti)*0.157/m.sqrt(Tc/1000)

# Resistencias de puesta a tierra

res_puesta_tierra=resisti_apare*((1/(longi_conduc_horiz+longi_total_vari))+(1/m.sqrt(20*area_malla))*(1+(1/(1+prof_enterra*m.sqrt(20/area_malla)/100))))

# Cálculo de la tensión de la malla

C45=2*longi_conduc_horiz/longi_perim
D45=m.sqrt(longi_perim/(4*m.sqrt(area_malla)))

if flag4==1 or flag4==2:
    E45=1
elif flag4==3:
    E45=(largo*ancho/area_malla)**(0.7*area_malla/(largo*ancho))

else:
    print("Error en el ingreso de datos")

n=C45*D45*E45# n

if flag==1:
    H45=1
elif flag==2:
    H45=1/(2*n)**(2/n)


G45=m.sqrt(1+0.01*prof_enterra)


ki=0.644+0.148*n # ki


ks=(1/m.pi)*((1/(2*prof_enterra/100))+(1/((lado_cuadri/100)+(prof_enterra/100)))+(100/lado_cuadri)*(1-0.5**(n-2)))


km = (1/(2*m.pi))*(m.log1p((((lado_cuadri*0.01)**2)/(16*prof_enterra*0.01*diam))+(((lado_cuadri*0.01+2*0.01*prof_enterra)**2)/(8*lado_cuadri*0.01*diam))-((prof_enterra*0.01)/(4*diam))-1)+((H45/G45)*m.log1p(8/(m.pi*((2*n)-1))-1)))
# Se calcula la máxima corriente de malla
# 0,6 ; I03 datos de la subestación del diseño
IG = (1)*(Sf)*(I03)
##print("Resitividad = ",resisti_apare)
##print("n = ",n)
##print(" km = ",km)
##print(" ks = ",ks)
##print(" ki = ",ki)
##print("Longitud total =",longi_conduc_horiz)
##print("IG =",IG)
##input()
# GPR
GPR = round(IG) * round(res_puesta_tierra,2)

Em =(resisti_apare*IG*km*ki)/(longi_conduc_horiz+(1.55+1.22*(longi_vari*0.01/(m.sqrt(largo**2+ancho**2))))*longi_total_vari)

Es =(resisti_apare*IG*ks*ki)/(0.75*longi_conduc_horiz+0.85*longi_total_vari)
borrarPantalla()

print (" \n")
print ("*************************************************************************\n")
print("DATOS DISEÑO PRELIMINAR:")
print ("*************************************************************************\n")
print(f'''
Diseño de malla de puesta a tierra {tipomalla }
________________________________________________________________________________
Resistencia objetivo menor = {res_menor}[Ohm]
________________________________________________________________________________
Resistividad aparente del terreno = {resisti_apare}[Ohm_m]
________________________________________________________________________________
Corriente de falla trifasica a tierra en el primario = {I_Falla}[A]
________________________________________________________________________________
Tiempo de despeje de la malla  = {Tc}[ms]
________________________________________________________________________________
Material del conductor: {M}[40°C]
________________________________________________________________________________
Resisitividad capa superficial = {resisti} [Ohm_m]
________________________________________________________________________________
Diámetro del conductor = {diam}[mm]      Calibre sugerido: {calibre}
________________________________________________________________________________
Longitud conductor horizontal = {longi_conduc_horiz}[m]
________________________________________________________________________________
Longitud total de varillas = {longi_total_vari}[m]
________________________________________________________________________________
Longitud total del perímetro = {longi_perim}[m]
________________________________________________________________________________
Área de la malla = {area_malla}[m^2]
_______________________________________________________________________________
Tensión de paso 50kg = {round(t_paso_tolerable50,3)} [V]
_______________________________________________________________________________
Tensión de contacto 50kg = {round(t_contac_tolerable50,3)} [V]
________________________________________________________________________________
Tensión de paso 70kg = {round(t_paso_tolerable70,3)} [V]

Tensión de contacto 70kg = {round(t_contac_tolerable70,3)} [V]
________________________________________________________________________________

Resistencia de puesta a tierra = {round(res_puesta_tierra,2)}[Ohms]
_______________________________________________________________________________
Máxima corriente de malla  {round(IG)} [A]     GPR = {GPR}[V]
_______________________________________________________________________________

Tensión de malla Em = {Em} [V]     Enter para continuar...
_______________________________________________________________________________

''')
input()

borrarPantalla()
if GPR > t_contac_tolerable:

    com1 = "El GPR"
    com2 = "el voltaje de contacto tolerable"
    d1 = 0
else:

    com1 = "El voltaje de contacto tolerable"
    com2 = "GPR"
    d1 = 1

if Em > t_contac_tolerable:

    com3 = "El Voltaje de malla"
    com4 = "el voltaje de contacto tolerable"
    d2 = 0
else:

    com3 = "El voltaje de contacto tolerable "
    com4 = "el Voltaje de malla"
    d2 = 1

if Es > t_paso_tolerable:

    com5 = "El Voltaje de paso calculado"
    com6 = "el voltaje de paso tolerable"
    d3 = 0
else:

    com5 = "El voltaje de paso tolerable"
    com6 = "el Voltaje de paso calculado"
    nota1 ="Se cumple con la resistencia mínima sugerida"
    d3 = 1

if res_puesta_tierra > res_menor:

    com7 = "La resistencia calculada"
    com8 = "la mínima reistencia sugerida por el RETIE"
    nota1 = f'''
    Si no es posible obtener una resistencia de puesta a tierra por debajo
    de los límites sugeridos por el RETIE, se puede continuar con la constr-
    ucción  de la malla, siempre y cuando se cumpla con los criterios
    de tensión de contacto y de paso mínimos tolerables.
    '''
    d4 = 0
else:

    com7 = "La mínima reistencia sugerida RETIE"
    com8 = "la resistencia calculada"
    d4 = 1

n = d2*d3

if n == 0:
    diag = "Modigique su diseño"
else:
    diag = "Diseño exitoso! "

borrarPantalla()
print (" \n")
print(f'''

********************************************************************************
ANÁLISI COMPARATIVO
********************************************************************************
GPR = {GPR}
-------------------------------------------------------------------------------
Voltaje de contacto tolerable  = {round(t_contac_tolerable,3)}[V]

Voltaje de malla  = {round(Em,3)}[V]

{com3} es mayor que {com4}
-------------------------------------------------------------------------------

Vpaso tolerable = {round(t_paso_tolerable,3)}[V]

Vpaso caculado =  {round(Es,3)} [V]

{com5} es mayor que {com6}
-------------------------------------------------------------------------------

Resistencia de puesta a tierra sugerida =  {res_menor}[Ohms]

Resistencia de puesta tierra malla =  {round(res_puesta_tierra,2)}[Ohms]

{com7} es mayor que {com8}

Nota :
-------------------------------------------------------------------------------
Diagnóstico : {diag}
_______________________________________________________________________________

''')
"""
Se calculael numero de cruces en forma de X,L y T
"""
input()
if flag4==1 or flag4==2:
    lado_cuadri_m=lado_cuadri/100
    nL=4
    nx=((largo/lado_cuadri_m)-1)*((ancho/lado_cuadri_m)-1)
    nT=(((largo/lado_cuadri_m)-1)+((ancho/lado_cuadri_m)-1))*2
    forma=("Rectangular")
elif flag4==3:
    nL=5
    lado_cuadri_m=lado_cuadri/100
    nx=1+((largo/lado_cuadri_m)-1)*((l1/lado_cuadri_m)-1)+((l2/lado_cuadri_m)-1)*((ancho-l1)/lado_cuadri_m)
    nT=((2*(ancho+largo))/lado_cuadri_m)-6
    forma=("forma L")
"""
Añadimos un diccionario con la cantidad de soldadura por calibre

"""

LibreriaT={
   "2/0 AWG":90 ,
   "4/0 AWG":150 ,
   "250 kcmil":150 ,
   "300 kcmil":200 ,
   "350 kcmil":200
   }
LibreriaX={
   "2/0 AWG":115 ,
   "4/0 AWG":200 ,
   "250 kcmil":200 ,
   "300 kcmil":250 ,
   "350 kcmil":250
   }
LibreriaL={
   "2/0 AWG":90 ,
   "4/0 AWG":150 ,
   "250 kcmil":150 ,
   "300 kcmil":200 ,
   "350 kcmil":200
   }
PrecioSoldadura={
    90: 13800,
    115:16800,
    150:21900,
    200:26200,
    250:32550,
   }
PrecioCobreDuro={
   "2/0 AWG":43200 ,
   "4/0 AWG":67200 ,
   "250 kcmil":80150 ,
   "300 kcmil":95000 ,
   "350 kcmil":112250
   }
SoldaduraT=LibreriaT[calibre]
SoldaduraL=LibreriaL[calibre]
SoldaduraX=LibreriaX[calibre]
PrecioT=PrecioSoldadura[SoldaduraT]
PrecioL=PrecioSoldadura[SoldaduraL]
PrecioX=PrecioSoldadura[SoldaduraX]
PrecioCobre=PrecioCobreDuro[calibre]
print(f'''

********************************************************************************
CANTIDAD DE CRUCES EN EL CIRCUITO
********************************************************************************
La malla tiene forma {forma}
-------------------------------------------------------------------------------

Numero de cruces L:{nL}
Soldadura por cruce : {SoldaduraL} gr
Precio Unitario:{PrecioL}
Precio total soldadura .exo L:{PrecioL*nL} COP

-------------------------------------------------------------------------------

Numero de cruces T:{nT}
Soldadura por cruce : {SoldaduraT} gr
Precio Unitario:{PrecioT}
Precio total soldadura .exo T:{PrecioT*nT} COP

-------------------------------------------------------------------------------

Numero de cruces X:{nx}
Soldadura por cruce : {SoldaduraX} gr
Precio Unitario:{PrecioX}
Precio total soldadura .exo L:{PrecioX*nx} COP

-------------------------------------------------------------------------------

PRECIO TOTAL POR SOLDADURA EXOTERMICA: {PrecioX*nx+PrecioT*nT+PrecioL*nL} COP

-------------------------------------------------------------------------------
El total de longitud total de la malla :{round(longi_conduc_horiz)}  [m]

De un calibre minimo sugerido de {calibre}
_______________________________________________________________________________

''')

input()


if flag==1:
    print(f'''

********************************************************************************
Varillas
********************************************************************************
El numero de varillas son {num_vari} , de una longitud {longi_vari} [cm]

Para una longitud total entre varillas y malla de :{round(longi_conduc_horiz)+longi_vari*0.01} [m]
El precio por metro es   :{PrecioCobre} COP
Precio total de longitud :{(round(longi_conduc_horiz)+longi_vari)*PrecioCobre} COP
_______________________________________________________________________________

''')


"""
Se realiza el dibujo de la malla de puesta a tierra
"""
if flag4==1 or flag4==2:
    lado_cuadri_m=lado_cuadri/100
    n_largo=int((largo/lado_cuadri_m)+1)
    n_ancho=int((ancho/lado_cuadri_m)+1)

    x,y=np.linspace(0,ancho,n_ancho),np.linspace(0,largo,n_largo)
    # Valores de x, y para cuadrícula de la malla
    X,Y=np.meshgrid(x,y)
    # Ecuación zn = f(x,y)
    Z1=Y


    fig=plt.figure()
    ax=fig.add_subplot(projection='3d')
    # alpha da la tranparencia a la superficie
    #ax.plot_surface(X,Y,Z1,alpha=0.9,cmap=cm.Accent,rstride=100,cstride=100)
    ax.plot_wireframe(X,Y,Z1,alpha=1,rstride=1,cstride=1)
    #ax.plot_surface(X,Y,Z2,alpha= 0.9,cmap=cm.Paired,rstride=100,cstride=100)
    #ax.plot_surface(X,Y,Z3,alpha=0.9,cmap=cm.Pastel1,rstride=100,cstride=100)
    plt.title("Malla")
    plt.show()
elif flag4==3:

    lado_cuadri_m=lado_cuadri/100
    n_largo=int((largo/lado_cuadri_m)+1)
    n_ancho=int((l1/lado_cuadri_m)+1)
    n_xmalla2=int(((ancho-l1)/lado_cuadri_m)+1)
    n_ymalla2=int(((l2)/lado_cuadri_m)+1)

    x,y=np.linspace(0,l1,n_ancho),np.linspace(0,largo,n_largo)
    x2,y2=np.linspace(l1,ancho,n_xmalla2),np.linspace(0,l2,n_ymalla2)
    # Valores de x, y para cuadrícula de la malla
    X,Y=np.meshgrid(x,y)
    # Ecuación zn = f(x,y)
    X2,Y2=np.meshgrid(x2,y2)
    Z1=Y
    Z2=Y2
    fig=plt.figure()
    ax=fig.add_subplot(projection='3d')
    # alpha da la tranparencia a la superficie
    #ax.plot_surface(X,Y,Z1,alpha=0.9,cmap=cm.Accent,rstride=100,cstride=100)
    ax.plot_wireframe(X,Y,Z1,alpha=1,rstride=1,cstride=1)
    ax.plot_wireframe(X2,Y2,Z2,alpha=1,rstride=1,cstride=1)
# Out:
# ¿Desea ejecutar un programa para  STP tipo poste? (s/n): n
# *************************************************************************
#
# DISEÑO DE MALLA DE PUESTA A TIERRA DE GEOMETRÍA RECTANGULAR, CUADRADA
# Y EN FORMA DE 'L' SEGÚN NORMA IEEE-80/2000
# V2022_1
# ELABORADO POR: MARIO LEÓN HOYOS LONDOÑO
# MAYO DE 2022
# EMPRESA ENERVOLT S.A.S.
# *************************************************************************
#
# *************************************************************************
#
# SELECCIONE EL NÚMERO CORRESPONDIENTE AL TIPO DE SUBESTACIÓN:
# -------------------------------------------------------------------------
#
# 1) Subestaciones de alta y extra alta tensión
# 2) Subestaciones de media tensión en poste
# 3) Subestaciones de media tensión de uso interior
#  Número tipo de subestación = 3
#
#
# *************************************************************************
#
# INGRESE EL VALOR DE LA RESISTIVIDAD APARENTE DEL TERRENO HOMOGENEO
# ...
